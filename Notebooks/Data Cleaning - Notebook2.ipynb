# %%
import pandas as pd

# %%
data = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
data.shape
# Out:
# (8523, 12)

# %%
test.shape
# Out:
# (5681, 11)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
data['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
data[data['Item_Identifier']=='FDW13']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 256            FDW13          8.5          Low Fat         0.098438    Canned
# 1141           FDW13          8.5          Low Fat         0.097866    Canned
# 2190           FDW13          8.5          Low Fat         0.098283    Canned
# 3928           FDW13          NaN          Low Fat         0.097411    Canned
# 3978           FDW13          8.5          Low Fat         0.098037    Canned
# 6499           FDW13          8.5          Low Fat         0.098083    Canned
# 6587           FDW13          8.5          low fat         0.163839    Canned
# 7029           FDW13          8.5          Low Fat         0.097803    Canned
# 8025           FDW13          NaN          Low Fat         0.171384    Canned
# 8032           FDW13          8.5          Low Fat         0.097885    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data[data['Item_Identifier']=='FDG33']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 231            FDG33          NaN          Regular         0.139561   Seafood
# 1202           FDG33        5.365          Regular         0.140525   Seafood
# 1575           FDG33          NaN          Regular         0.245543   Seafood
# 2728           FDG33        5.365          Regular         0.234733   Seafood
# 4747           FDG33        5.365          Regular         0.140458   Seafood
# 5164           FDG33        5.365          Regular         0.140240   Seafood
# 6112           FDG33        5.365          Regular         0.141034   Seafood
# 7011           FDG33        5.365          Regular         0.140812   Seafood
# 7098           FDG33        5.365          Regular         0.140124   Seafood
# 7726           FDG33        5.365          Regular         0.140214   Seafood
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data[data['Item_Identifier']=='NCY18']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 342            NCY18        7.285          Low Fat         0.031126
# 736            NCY18        7.285          Low Fat         0.031146
# 1639           NCY18        7.285          Low Fat         0.031215
# 1756           NCY18        7.285          Low Fat         0.031328
# 2079           NCY18        7.285          Low Fat         0.052141
# 2976           NCY18        7.285          Low Fat         0.031152
# 4233           NCY18          NaN          Low Fat         0.031001
# 6050           NCY18        7.285          Low Fat         0.031200
# 7869           NCY18        7.285          Low Fat         0.031279
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 342   Household  174.3054            OUT013                       1987
# 736   Household  173.6054            OUT035                       2004
# 1639  Household  177.1054            OUT045                       2002
# ...

# %% [markdown]
# * We can understand one pattern here is like Item_Identifier and Item_Type shares the same thing, in the Item_Identifier we have lot of ctegorical values so instead of using Item_Identifier we can use Item_Type for further works.

# %%
data['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
data['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
data[data['Outlet_Identifier'] == 'OUT027'].sample(21).T
# Out:
#                                             2053                   5084  \
# Item_Identifier                            FDG44                  FDP56
# Item_Weight                                  NaN                    NaN
# Item_Fat_Content                         Low Fat                Low Fat
# Item_Visibility                              0.0               0.046259
# Item_Type                  Fruits and Vegetables  Fruits and Vegetables
# Item_MRP                                 55.7298                47.4692
# Outlet_Identifier                         OUT027                 OUT027
# Outlet_Establishment_Year                   1985                   1985
# Outlet_Size                               Medium                 Medium
# Outlet_Location_Type                      Tier 3                 Tier 3
# Outlet_Type                    Supermarket Type3      Supermarket Type3
# Item_Outlet_Sales                      2804.3496              1576.6144
#
# ...

# %%
data[data['Outlet_Identifier'] == 'OUT013'].sample(21).T
# Out:
#                                             2228               1511  \
# Item_Identifier                            FDQ19              NCC31
# Item_Weight                                 7.35               8.02
# Item_Fat_Content                         Regular            Low Fat
# Item_Visibility                         0.014353                0.0
# Item_Type                  Fruits and Vegetables          Household
# Item_MRP                                242.6512           157.7972
# Outlet_Identifier                         OUT013             OUT013
# Outlet_Establishment_Year                   1987               1987
# Outlet_Size                                 High               High
# Outlet_Location_Type                      Tier 3             Tier 3
# Outlet_Type                    Supermarket Type1  Supermarket Type1
# Item_Outlet_Sales                       969.4048          1713.7692
#
#                                             3708               3454  \
# ...

# %%
data[data['Outlet_Identifier'] == 'OUT046'].sample(21).T
# Out:
#                                         6113               2591  \
# Item_Identifier                        FDE38              DRD12
# Item_Weight                             6.52               6.96
# Item_Fat_Content                     Low Fat            Low Fat
# Item_Visibility                     0.044607           0.077194
# Item_Type                             Canned        Soft Drinks
# Item_MRP                            164.2842            89.9146
# Outlet_Identifier                     OUT046             OUT046
# Outlet_Establishment_Year               1997               1997
# Outlet_Size                            Small              Small
# Outlet_Location_Type                  Tier 1             Tier 1
# Outlet_Type                Supermarket Type1  Supermarket Type1
# Item_Outlet_Sales                  2818.3314          1277.0044
#
#                                             8331                   1522  \
# ...

# %%
data[data['Outlet_Identifier'] == 'OUT017'].sample(21).T
# Out:
#                                         1475               2272  \
# Item_Identifier                        FDP52              DRC01
# Item_Weight                             18.7               5.92
# Item_Fat_Content                     Regular            Regular
# Item_Visibility                     0.071092           0.019309
# Item_Type                       Frozen Foods        Soft Drinks
# Item_MRP                             228.601            49.0692
# Outlet_Identifier                     OUT017             OUT017
# Outlet_Establishment_Year               2007               2007
# Outlet_Size                              NaN                NaN
# Outlet_Location_Type                  Tier 2             Tier 2
# Outlet_Type                Supermarket Type1  Supermarket Type1
# Item_Outlet_Sales                   4823.721           1478.076
#
#                                         7125               3394  \
# Item_Identifier                        FDW09              FDV16
# ...

# %% [markdown]
# * There is also a pattern here like Outlet_Identifier and Outlet_Type shares the same thing, in the Outlet_Identifier we have lot of categorical values so instead of using Outlet_Identifier we can use Outlet_Type for further works.
# * Other Pattern is Outlet_Identifier Indentifies the Outlet_Location_Type of same Outlet_Type.

# %%
data.drop(columns=['Item_Identifier', 'Outlet_Identifier'], inplace=True)

# %%
data['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
data[data['Outlet_Establishment_Year']==1998][['Outlet_Type', 'Outlet_Location_Type']].value_counts()
# Out:
# Outlet_Type    Outlet_Location_Type
# Grocery Store  Tier 3                  555
# dtype: int64

# %%
data[data['Outlet_Establishment_Year']==1998][['Item_Type','Outlet_Type', 'Outlet_Location_Type']].value_counts()
# Out:
# Item_Type              Outlet_Type    Outlet_Location_Type
# Fruits and Vegetables  Grocery Store  Tier 3                  79
# Snack Foods            Grocery Store  Tier 3                  71
# Household              Grocery Store  Tier 3                  67
# Frozen Foods           Grocery Store  Tier 3                  54
# Dairy                  Grocery Store  Tier 3                  43
# Baking Goods           Grocery Store  Tier 3                  42
# Health and Hygiene     Grocery Store  Tier 3                  37
# Canned                 Grocery Store  Tier 3                  35
# Meat                   Grocery Store  Tier 3                  34
# Soft Drinks            Grocery Store  Tier 3                  28
# Breads                 Grocery Store  Tier 3                  17
# Hard Drinks            Grocery Store  Tier 3                  16
# Others                 Grocery Store  Tier 3                  10
# Breakfast              Grocery Store  Tier 3                   9
# ...

# %%
for i in data['Outlet_Establishment_Year'].unique():
    print(f'Year {i}')
    print(data[data['Outlet_Establishment_Year']==i][['Outlet_Size','Outlet_Type', 'Outlet_Location_Type']].value_counts())
    print('----------------------------------------------------------------------------------')
# Out:
# Year 1999
# Outlet_Size  Outlet_Type        Outlet_Location_Type
# Medium       Supermarket Type1  Tier 1                  930
# dtype: int64
# ----------------------------------------------------------------------------------
# Year 2009
# Outlet_Size  Outlet_Type        Outlet_Location_Type
# Medium       Supermarket Type2  Tier 3                  928
# dtype: int64
# ----------------------------------------------------------------------------------
# Year 1998
# Series([], dtype: int64)
# ----------------------------------------------------------------------------------
# Year 1987
# Outlet_Size  Outlet_Type        Outlet_Location_Type
# High         Supermarket Type1  Tier 3                  932
# dtype: int64
# ----------------------------------------------------------------------------------
# Year 1985
# Outlet_Size  Outlet_Type        Outlet_Location_Type
# Medium       Supermarket Type3  Tier 3                  935
# ...

# %%
data[data['Outlet_Establishment_Year']==2007][['Outlet_Size','Outlet_Type', 'Outlet_Location_Type']]
# Out:
#      Outlet_Size        Outlet_Type Outlet_Location_Type
# 9            NaN  Supermarket Type1               Tier 2
# 25           NaN  Supermarket Type1               Tier 2
# 53           NaN  Supermarket Type1               Tier 2
# 54           NaN  Supermarket Type1               Tier 2
# 73           NaN  Supermarket Type1               Tier 2
# ...          ...                ...                  ...
# 8493         NaN  Supermarket Type1               Tier 2
# 8494         NaN  Supermarket Type1               Tier 2
# 8496         NaN  Supermarket Type1               Tier 2
# 8500         NaN  Supermarket Type1               Tier 2
# 8501         NaN  Supermarket Type1               Tier 2
#
# [926 rows x 3 columns]

# %% [markdown]
# * The Sales data of year 1999 is from Supermarket Type1 which is located in Tier 1 Cities and have Medium size. And this pattern is applicable for all the years, this is not very convinent as such.
# * Instead of this we can convert Establishment year into the age of Outlet, so we can derive the sales information in more convinent way, such as we can ask a question like: if any outlet is 20 years old situated in tier 3 city and has medium in size so how much sales has been genrated from there.

# %%
# substract current year from establishment year.
data['Age_Outlet'] = 2022 - data['Outlet_Establishment_Year']

# %%
# drop the Establishment year
data.drop(columns=['Outlet_Establishment_Year'], inplace=True)

# %%
data[data['Age_Outlet']==13]['Item_Outlet_Sales'].sum()
# Out:
# 1851822.83

# %%
data.sample(10).T
# Out:
#                                    8264                   1863  \
# Item_Weight                        13.6                  19.35
# Item_Fat_Content                Low Fat                Regular
# Item_Visibility                0.009991               0.021453
# Item_Type                     Household  Fruits and Vegetables
# Item_MRP                        175.537               120.3098
# Outlet_Size                       Small                  Small
# Outlet_Location_Type             Tier 2                 Tier 2
# Outlet_Type           Supermarket Type1      Supermarket Type1
# Item_Outlet_Sales              3705.177              2530.7058
# Age_Outlet                           18                     18
#
#                                    8002                   2784  \
# Item_Weight                       17.25                   11.5
# Item_Fat_Content                Low Fat                     LF
# Item_Visibility                0.113518               0.173483
# ...
