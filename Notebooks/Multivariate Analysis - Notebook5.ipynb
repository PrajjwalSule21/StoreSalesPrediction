# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
data = pd.read_csv('Train.csv')
data['Age_Outlet'] = datetime.now().year - data['Outlet_Establishment_Year']
data.drop(columns=['Outlet_Establishment_Year', 'Outlet_Identifier', 'Item_Identifier'], inplace=True)

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].str.replace('LF','Low Fat')
data['Item_Fat_Content'] = data['Item_Fat_Content'].str.replace('low fat','Low Fat')
data['Item_Fat_Content'] = data['Item_Fat_Content'].str.replace('reg','Regular')

# %%
data.sample(5)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 4715          NaN          Low Fat         0.121765     Health and Hygiene
# 4061        12.80          Low Fat         0.152378                 Others
# 2105        11.80          Regular         0.014075           Frozen Foods
# 3395          NaN          Regular         0.043978  Fruits and Vegetables
# 1471        13.85          Low Fat         0.034640            Hard Drinks
#
#       Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 4715  264.1884       Small               Tier 1      Grocery Store
# 4061  108.1938         NaN               Tier 3      Grocery Store
# 2105  176.8344        High               Tier 3  Supermarket Type1
# 3395  178.4318      Medium               Tier 3  Supermarket Type3
# 1471  116.1492         NaN               Tier 2  Supermarket Type1
#
#       Item_Outlet_Sales  Age_Outlet
# 4715           264.9884          37
# 4061           428.7752          24
# ...

# %%
sns.scatterplot(data['Item_Outlet_Sales'], data['Item_MRP'], hue=data['Item_Weight'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_MRP'>

# %%
sns.scatterplot(data['Item_Outlet_Sales'], data['Item_MRP'], hue=data['Item_Visibility'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_MRP'>

# %%
sns.scatterplot(data['Item_Outlet_Sales'], data['Item_MRP'], hue=data['Outlet_Type'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_MRP'>

# %%
sns.scatterplot(data['Item_Outlet_Sales'], data['Item_Visibility'], hue=data['Outlet_Type'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_Visibility'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Item_Type'], data['Item_Outlet_Sales'], hue=data['Outlet_Type'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Item_Type'], data['Item_Outlet_Sales'], hue=data['Outlet_Location_Type'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Item_Type'], data['Item_Outlet_Sales'], hue=data['Item_Fat_Content'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Item_Type'], data['Item_Outlet_Sales'], hue=data['Outlet_Size'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>
