# %%
import pandas as pd

# %%
data = pd.read_csv('Train.csv')

# %%
data.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6562           FDD39        16.70          Low Fat         0.070441
# 5954           DRI59          NaN          Low Fat         0.040637
# 1058           FDH33        12.85          Low Fat         0.122221
# 5633           DRC36        13.00              reg         0.044976
# 8487           DRG13          NaN          Low Fat         0.037006
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 6562        Dairy  216.8850            OUT018                       2009
# 5954  Hard Drinks  224.6088            OUT027                       1985
# 1058  Snack Foods   45.9428            OUT018                       2009
# 5633  Soft Drinks  176.2054            OUT035                       2004
# 8487  Soft Drinks  164.7526            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.describe(include='all').T
# Out:
#                             count unique                    top  freq  \
# Item_Identifier              8523   1559                  FDW13    10
# Item_Weight                7060.0    NaN                    NaN   NaN
# Item_Fat_Content             8523      5                Low Fat  5089
# Item_Visibility            8523.0    NaN                    NaN   NaN
# Item_Type                    8523     16  Fruits and Vegetables  1232
# Item_MRP                   8523.0    NaN                    NaN   NaN
# Outlet_Identifier            8523     10                 OUT027   935
# Outlet_Establishment_Year  8523.0    NaN                    NaN   NaN
# Outlet_Size                  6113      3                 Medium  2793
# Outlet_Location_Type         8523      3                 Tier 3  3350
# Outlet_Type                  8523      4      Supermarket Type1  5577
# Item_Outlet_Sales          8523.0    NaN                    NaN   NaN
#
# ...

# %% [markdown]
# #### Observations
# * We Have 8523 Rows and 12 Columns.
# * In this data we have 7 Categical Columns and 5 Numerical Columns.
# * Categorical Columns: Item_Identifier, Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Size, Outlet_Location_Type.
# * Numerical Columns: Item_Weight, Item_Visibility, Item_MRP, Outlet_Establishment_Year, Item_Outlet_Sales.
# * Item_Weight and Outlet_Size have some null values.
# * We can drop Item_identifier and Outler_Identifier becasue these are not very useful while preidction instead of these columns we can use Item_Type and Outlet_Type.
# * We have one year column Outlet_Establishment_Year so we can transform this into Age_of_Outlet, where we subtract the current year - Outlet_Establishment_year so with this w can derive the age of Outlets.
